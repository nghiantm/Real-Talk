# %%
import os
from dotenv import load_dotenv
load_dotenv()
from concurrent.futures import ThreadPoolExecutor
from openai import OpenAI
import time

# %% [markdown]
# Open guideline descriptions dir and read into a dictionary

# %%
dirPath = "../data/guideline_desc"

descFiles = os.listdir(dirPath)

guidelines = {}

for filename in descFiles:
    filePath = os.path.join(dirPath, filename)

    if os.path.isfile(filePath):
        with open(filePath, "r") as file:
            fileContent = file.read
            # No extension filename
            strippedFilename = os.path.splitext(filename)[0]
            guidelines[strippedFilename] = fileContent

# %% [markdown]
# Create directories for training data, if not already created

# %%
for key in guidelines:
    if not os.path.exists(f"../data/guideline_data/{key}"):
        os.makedirs(f"../data/guideline_data/{key}")

# %% [markdown]
# Promt for generating

# %%
prompt = """
Your role is to generate a potential statement from a Spanish speaker that would be categorized as "{level}".

Here is the description for "{level}":

"{description}"

Using this context, generate 5 statements that would be classified as coming from an "{level}" Spanish speaker. The statements should be rather brief, as if they were part of a conversation, but need not only be one sentence. Each statement should vary in length, from 1-3 sentences. Only provide the statements - do NOT provide English translations.
"""

# %%
openAI_client = OpenAI(api_key=os.environ.get("OPENAI_KEY"))

def generateLevel(level, description, i):
    print(f"Generating level {level} | {i}")
    
    chatCompletion = openAI_client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt.format(level=level, description=description),
            }
        ],
        model="gpt-3.5-turbo",
        temperature=1.3,
        frequency_penalty=0.7
    )

    response = chatCompletion.choices[0].message.content

    with open(f"../data/guideline_data/{level}/{i}.txt", "w") as file:
        file.write(response)

# %% [markdown]
# I was going to benchmark between single thread and multithread, but single threaded speed almost killed me, so let's just stick to multithreaded :)

# %%
'''
# Single threaded
for level, description in guidelines.items():
    for i in range(20):
        generateLevel(level, description, i)
'''

with ThreadPoolExecutor() as executor:
    for level, description in guidelines.items():
        futures = []
        for i in range(20):
            futures.append(executor.submit(generateLevel, level, description, i))
            # Delay to preserve my query per second limit
            time.sleep(.5)

        # Wait for all tasks to complete before moving to the next level
        for future in futures:
            future.result()
# Out:
# Generating level Advanced Mid | 0
# Generating level Advanced Mid | 1
# Generating level Advanced Mid | 2
# Generating level Advanced Mid | 3
# Generating level Advanced Mid | 4
# Generating level Advanced Mid | 5
# Generating level Advanced Mid | 6
# Generating level Advanced Mid | 7
# Generating level Advanced Mid | 8
# Generating level Advanced Mid | 9
# Generating level Advanced Mid | 10
# Generating level Advanced Mid | 11
# Generating level Advanced Mid | 12
# Generating level Advanced Mid | 13
# Generating level Advanced Mid | 14
# Generating level Advanced Mid | 15
# Generating level Advanced Mid | 16
# Generating level Advanced Mid | 17
# Generating level Advanced Mid | 18
# Generating level Advanced Mid | 19
# Generating level Distinguished | 0
# Generating level Distinguished | 1
# Generating level Distinguished | 2
# Generating level Distinguished | 3
# Generating level Distinguished | 4
# Generating level Distinguished | 5
# Generating level Distinguished | 6
# Generating level Distinguished | 7
# Generating level Distinguished | 8
# Generating level Distinguished | 9
# Generating level Distinguished | 10
# Generating level Distinguished | 11
# Generating level Distinguished | 12
# Generating level Distinguished | 13
# Generating level Distinguished | 14
# Generating level Distinguished | 15
# Generating level Distinguished | 16
# Generating level Distinguished | 17
# Generating level Distinguished | 18
# Generating level Distinguished | 19
# Generating level Advanced Low | 0
# Generating level Advanced Low | 1
# Generating level Advanced Low | 2
# Generating level Advanced Low | 3
# Generating level Advanced Low | 4
# Generating level Advanced Low | 5
# Generating level Advanced Low | 6
# Generating level Advanced Low | 7
# Generating level Advanced Low | 8
# Generating level Advanced Low | 9
# Generating level Advanced Low | 10
# Generating level Advanced Low | 11
# Generating level Advanced Low | 12
# Generating level Advanced Low | 13
# Generating level Advanced Low | 14
# Generating level Advanced Low | 15
# Generating level Advanced Low | 16
# Generating level Advanced Low | 17
# Generating level Advanced Low | 18
# Generating level Advanced Low | 19
# Generating level Intermediate High | 0
# Generating level Intermediate High | 1
# Generating level Intermediate High | 2
# Generating level Intermediate High | 3
# Generating level Intermediate High | 4
# Generating level Intermediate High | 5
# Generating level Intermediate High | 6
# Generating level Intermediate High | 7
# Generating level Intermediate High | 8
# Generating level Intermediate High | 9
# Generating level Intermediate High | 10
# Generating level Intermediate High | 11
# Generating level Intermediate High | 12
# Generating level Intermediate High | 13
# Generating level Intermediate High | 14
# Generating level Intermediate High | 15
# Generating level Intermediate High | 16
# Generating level Intermediate High | 17
# Generating level Intermediate High | 18
# Generating level Intermediate High | 19
# Generating level Novice Low | 0
# Generating level Novice Low | 1
# Generating level Novice Low | 2
# Generating level Novice Low | 3
# Generating level Novice Low | 4
# Generating level Novice Low | 5
# Generating level Novice Low | 6
# Generating level Novice Low | 7
# Generating level Novice Low | 8
# Generating level Novice Low | 9
# Generating level Novice Low | 10
# Generating level Novice Low | 11
# Generating level Novice Low | 12
# Generating level Novice Low | 13
# Generating level Novice Low | 14
# Generating level Novice Low | 15
# Generating level Novice Low | 16
# Generating level Novice Low | 17
# Generating level Novice Low | 18
# Generating level Novice Low | 19
# Generating level Intermediate Mid | 0
# Generating level Intermediate Mid | 1
# Generating level Intermediate Mid | 2
# Generating level Intermediate Mid | 3
# Generating level Intermediate Mid | 4
# Generating level Intermediate Mid | 5
# Generating level Intermediate Mid | 6
# Generating level Intermediate Mid | 7
# Generating level Intermediate Mid | 8
# Generating level Intermediate Mid | 9
# Generating level Intermediate Mid | 10
# Generating level Intermediate Mid | 11
# Generating level Intermediate Mid | 12
# Generating level Intermediate Mid | 13
# Generating level Intermediate Mid | 14
# Generating level Intermediate Mid | 15
# Generating level Intermediate Mid | 16
# Generating level Intermediate Mid | 17
# Generating level Intermediate Mid | 18
# Generating level Intermediate Mid | 19
# Generating level Novice High | 0
# Generating level Novice High | 1
# Generating level Novice High | 2
# Generating level Novice High | 3
# Generating level Novice High | 4
# Generating level Novice High | 5
# Generating level Novice High | 6
# Generating level Novice High | 7
# Generating level Novice High | 8
# Generating level Novice High | 9
# Generating level Novice High | 10
# Generating level Novice High | 11
# Generating level Novice High | 12
# Generating level Novice High | 13
# Generating level Novice High | 14
# Generating level Novice High | 15
# Generating level Novice High | 16
# Generating level Novice High | 17
# Generating level Novice High | 18
# Generating level Novice High | 19
# Generating level Novice Mid | 0
# Generating level Novice Mid | 1
# Generating level Novice Mid | 2
# Generating level Novice Mid | 3
# Generating level Novice Mid | 4
# Generating level Novice Mid | 5
# Generating level Novice Mid | 6
# Generating level Novice Mid | 7
# Generating level Novice Mid | 8
# Generating level Novice Mid | 9
# Generating level Novice Mid | 10
# Generating level Novice Mid | 11
# Generating level Novice Mid | 12
# Generating level Novice Mid | 13
# Generating level Novice Mid | 14
# Generating level Novice Mid | 15
# Generating level Novice Mid | 16
# Generating level Novice Mid | 17
# Generating level Novice Mid | 18
# Generating level Novice Mid | 19
# Generating level Intermediate Low | 0
# Generating level Intermediate Low | 1
# Generating level Intermediate Low | 2
# Generating level Intermediate Low | 3
# Generating level Intermediate Low | 4
# Generating level Intermediate Low | 5
# Generating level Intermediate Low | 6
# Generating level Intermediate Low | 7
# Generating level Intermediate Low | 8
# Generating level Intermediate Low | 9
# Generating level Intermediate Low | 10
# Generating level Intermediate Low | 11
# Generating level Intermediate Low | 12
# Generating level Intermediate Low | 13
# Generating level Intermediate Low | 14
# Generating level Intermediate Low | 15
# Generating level Intermediate Low | 16
# Generating level Intermediate Low | 17
# Generating level Intermediate Low | 18
# Generating level Intermediate Low | 19
# Generating level Superior | 0
# Generating level Superior | 1
# Generating level Superior | 2
# Generating level Superior | 3
# Generating level Superior | 4
# Generating level Superior | 5
# Generating level Superior | 6
# Generating level Superior | 7
# Generating level Superior | 8
# Generating level Superior | 9
# Generating level Superior | 10
# Generating level Superior | 11
# Generating level Superior | 12
# Generating level Superior | 13
# Generating level Superior | 14
# Generating level Superior | 15
# Generating level Superior | 16
# Generating level Superior | 17
# Generating level Superior | 18
# Generating level Superior | 19
# Generating level Advanced High | 0
# Generating level Advanced High | 1
# Generating level Advanced High | 2
# Generating level Advanced High | 3
# Generating level Advanced High | 4
# Generating level Advanced High | 5
# Generating level Advanced High | 6
# Generating level Advanced High | 7
# Generating level Advanced High | 8
# Generating level Advanced High | 9
# Generating level Advanced High | 10
# Generating level Advanced High | 11
# Generating level Advanced High | 12
# Generating level Advanced High | 13
# Generating level Advanced High | 14
# Generating level Advanced High | 15
# Generating level Advanced High | 16
# Generating level Advanced High | 17
# Generating level Advanced High | 18
# Generating level Advanced High | 19

# %% [markdown]
# There are some files with lines between the lines. Now I remove it.

# %%
def removeBlankLines(path):
    with open(path, 'r') as file:
        lines = file.readlines()

    # Remove empty lines
    nonEmptyLine = [line.strip() for line in lines if line.strip()]

    with open(path, 'w') as file:
        file.write('\n'.join(nonEmptyLine))

def processDirBlankLines(path):
    for root, dirs, files in os.walk(path):
        for filename in files:
            if filename.endswith('.txt'):
                filePath = os.path.join(root, filename)
                removeBlankLines(filePath)
                print(f"Processed: {filePath}")

dirPath = '../data/guideline_data'
processDirBlankLines(dirPath)
# Out:
# Processed: ../data/guideline_data/Advanced High/15.txt
# Processed: ../data/guideline_data/Advanced High/14.txt
# Processed: ../data/guideline_data/Advanced High/16.txt
# Processed: ../data/guideline_data/Advanced High/17.txt
# Processed: ../data/guideline_data/Advanced High/13.txt
# Processed: ../data/guideline_data/Advanced High/12.txt
# Processed: ../data/guideline_data/Advanced High/10.txt
# Processed: ../data/guideline_data/Advanced High/11.txt
# Processed: ../data/guideline_data/Advanced High/9.txt
# Processed: ../data/guideline_data/Advanced High/8.txt
# Processed: ../data/guideline_data/Advanced High/5.txt
# Processed: ../data/guideline_data/Advanced High/4.txt
# Processed: ../data/guideline_data/Advanced High/6.txt
# Processed: ../data/guideline_data/Advanced High/7.txt
# Processed: ../data/guideline_data/Advanced High/3.txt
# Processed: ../data/guideline_data/Advanced High/2.txt
# Processed: ../data/guideline_data/Advanced High/0.txt
# Processed: ../data/guideline_data/Advanced High/1.txt
# Processed: ../data/guideline_data/Advanced High/19.txt
# Processed: ../data/guideline_data/Advanced High/18.txt
# Processed: ../data/guideline_data/Intermediate High/15.txt
# Processed: ../data/guideline_data/Intermediate High/14.txt
# Processed: ../data/guideline_data/Intermediate High/16.txt
# Processed: ../data/guideline_data/Intermediate High/17.txt
# Processed: ../data/guideline_data/Intermediate High/13.txt
# Processed: ../data/guideline_data/Intermediate High/12.txt
# Processed: ../data/guideline_data/Intermediate High/10.txt
# Processed: ../data/guideline_data/Intermediate High/11.txt
# Processed: ../data/guideline_data/Intermediate High/9.txt
# Processed: ../data/guideline_data/Intermediate High/8.txt
# Processed: ../data/guideline_data/Intermediate High/5.txt
# Processed: ../data/guideline_data/Intermediate High/4.txt
# Processed: ../data/guideline_data/Intermediate High/6.txt
# Processed: ../data/guideline_data/Intermediate High/7.txt
# Processed: ../data/guideline_data/Intermediate High/3.txt
# Processed: ../data/guideline_data/Intermediate High/2.txt
# Processed: ../data/guideline_data/Intermediate High/0.txt
# Processed: ../data/guideline_data/Intermediate High/1.txt
# Processed: ../data/guideline_data/Intermediate High/19.txt
# Processed: ../data/guideline_data/Intermediate High/18.txt
# Processed: ../data/guideline_data/Intermediate Mid/15.txt
# Processed: ../data/guideline_data/Intermediate Mid/14.txt
# Processed: ../data/guideline_data/Intermediate Mid/16.txt
# Processed: ../data/guideline_data/Intermediate Mid/17.txt
# Processed: ../data/guideline_data/Intermediate Mid/13.txt
# Processed: ../data/guideline_data/Intermediate Mid/12.txt
# Processed: ../data/guideline_data/Intermediate Mid/10.txt
# Processed: ../data/guideline_data/Intermediate Mid/11.txt
# Processed: ../data/guideline_data/Intermediate Mid/9.txt
# Processed: ../data/guideline_data/Intermediate Mid/8.txt
# Processed: ../data/guideline_data/Intermediate Mid/5.txt
# Processed: ../data/guideline_data/Intermediate Mid/4.txt
# Processed: ../data/guideline_data/Intermediate Mid/6.txt
# Processed: ../data/guideline_data/Intermediate Mid/7.txt
# Processed: ../data/guideline_data/Intermediate Mid/3.txt
# Processed: ../data/guideline_data/Intermediate Mid/2.txt
# Processed: ../data/guideline_data/Intermediate Mid/0.txt
# Processed: ../data/guideline_data/Intermediate Mid/1.txt
# Processed: ../data/guideline_data/Intermediate Mid/19.txt
# Processed: ../data/guideline_data/Intermediate Mid/18.txt
# Processed: ../data/guideline_data/Intermediate Low/15.txt
# Processed: ../data/guideline_data/Intermediate Low/14.txt
# Processed: ../data/guideline_data/Intermediate Low/16.txt
# Processed: ../data/guideline_data/Intermediate Low/17.txt
# Processed: ../data/guideline_data/Intermediate Low/13.txt
# Processed: ../data/guideline_data/Intermediate Low/12.txt
# Processed: ../data/guideline_data/Intermediate Low/10.txt
# Processed: ../data/guideline_data/Intermediate Low/11.txt
# Processed: ../data/guideline_data/Intermediate Low/9.txt
# Processed: ../data/guideline_data/Intermediate Low/8.txt
# Processed: ../data/guideline_data/Intermediate Low/5.txt
# Processed: ../data/guideline_data/Intermediate Low/4.txt
# Processed: ../data/guideline_data/Intermediate Low/6.txt
# Processed: ../data/guideline_data/Intermediate Low/7.txt
# Processed: ../data/guideline_data/Intermediate Low/3.txt
# Processed: ../data/guideline_data/Intermediate Low/2.txt
# Processed: ../data/guideline_data/Intermediate Low/0.txt
# Processed: ../data/guideline_data/Intermediate Low/1.txt
# Processed: ../data/guideline_data/Intermediate Low/19.txt
# Processed: ../data/guideline_data/Intermediate Low/18.txt
# Processed: ../data/guideline_data/Novice High/15.txt
# Processed: ../data/guideline_data/Novice High/14.txt
# Processed: ../data/guideline_data/Novice High/16.txt
# Processed: ../data/guideline_data/Novice High/17.txt
# Processed: ../data/guideline_data/Novice High/13.txt
# Processed: ../data/guideline_data/Novice High/12.txt
# Processed: ../data/guideline_data/Novice High/10.txt
# Processed: ../data/guideline_data/Novice High/11.txt
# Processed: ../data/guideline_data/Novice High/9.txt
# Processed: ../data/guideline_data/Novice High/8.txt
# Processed: ../data/guideline_data/Novice High/5.txt
# Processed: ../data/guideline_data/Novice High/4.txt
# Processed: ../data/guideline_data/Novice High/6.txt
# Processed: ../data/guideline_data/Novice High/7.txt
# Processed: ../data/guideline_data/Novice High/3.txt
# Processed: ../data/guideline_data/Novice High/2.txt
# Processed: ../data/guideline_data/Novice High/0.txt
# Processed: ../data/guideline_data/Novice High/1.txt
# Processed: ../data/guideline_data/Novice High/19.txt
# Processed: ../data/guideline_data/Novice High/18.txt
# Processed: ../data/guideline_data/Superior/15.txt
# Processed: ../data/guideline_data/Superior/14.txt
# Processed: ../data/guideline_data/Superior/16.txt
# Processed: ../data/guideline_data/Superior/17.txt
# Processed: ../data/guideline_data/Superior/13.txt
# Processed: ../data/guideline_data/Superior/12.txt
# Processed: ../data/guideline_data/Superior/10.txt
# Processed: ../data/guideline_data/Superior/11.txt
# Processed: ../data/guideline_data/Superior/9.txt
# Processed: ../data/guideline_data/Superior/8.txt
# Processed: ../data/guideline_data/Superior/5.txt
# Processed: ../data/guideline_data/Superior/4.txt
# Processed: ../data/guideline_data/Superior/6.txt
# Processed: ../data/guideline_data/Superior/7.txt
# Processed: ../data/guideline_data/Superior/3.txt
# Processed: ../data/guideline_data/Superior/2.txt
# Processed: ../data/guideline_data/Superior/0.txt
# Processed: ../data/guideline_data/Superior/1.txt
# Processed: ../data/guideline_data/Superior/19.txt
# Processed: ../data/guideline_data/Superior/18.txt
# Processed: ../data/guideline_data/Advanced Mid/15.txt
# Processed: ../data/guideline_data/Advanced Mid/14.txt
# Processed: ../data/guideline_data/Advanced Mid/16.txt
# Processed: ../data/guideline_data/Advanced Mid/17.txt
# Processed: ../data/guideline_data/Advanced Mid/13.txt
# Processed: ../data/guideline_data/Advanced Mid/12.txt
# Processed: ../data/guideline_data/Advanced Mid/10.txt
# Processed: ../data/guideline_data/Advanced Mid/11.txt
# Processed: ../data/guideline_data/Advanced Mid/9.txt
# Processed: ../data/guideline_data/Advanced Mid/8.txt
# Processed: ../data/guideline_data/Advanced Mid/5.txt
# Processed: ../data/guideline_data/Advanced Mid/4.txt
# Processed: ../data/guideline_data/Advanced Mid/6.txt
# Processed: ../data/guideline_data/Advanced Mid/7.txt
# Processed: ../data/guideline_data/Advanced Mid/3.txt
# Processed: ../data/guideline_data/Advanced Mid/2.txt
# Processed: ../data/guideline_data/Advanced Mid/0.txt
# Processed: ../data/guideline_data/Advanced Mid/1.txt
# Processed: ../data/guideline_data/Advanced Mid/19.txt
# Processed: ../data/guideline_data/Advanced Mid/18.txt
# Processed: ../data/guideline_data/Novice Mid/15.txt
# Processed: ../data/guideline_data/Novice Mid/14.txt
# Processed: ../data/guideline_data/Novice Mid/16.txt
# Processed: ../data/guideline_data/Novice Mid/17.txt
# Processed: ../data/guideline_data/Novice Mid/13.txt
# Processed: ../data/guideline_data/Novice Mid/12.txt
# Processed: ../data/guideline_data/Novice Mid/10.txt
# Processed: ../data/guideline_data/Novice Mid/11.txt
# Processed: ../data/guideline_data/Novice Mid/9.txt
# Processed: ../data/guideline_data/Novice Mid/8.txt
# Processed: ../data/guideline_data/Novice Mid/5.txt
# Processed: ../data/guideline_data/Novice Mid/4.txt
# Processed: ../data/guideline_data/Novice Mid/6.txt
# Processed: ../data/guideline_data/Novice Mid/7.txt
# Processed: ../data/guideline_data/Novice Mid/3.txt
# Processed: ../data/guideline_data/Novice Mid/2.txt
# Processed: ../data/guideline_data/Novice Mid/0.txt
# Processed: ../data/guideline_data/Novice Mid/1.txt
# Processed: ../data/guideline_data/Novice Mid/19.txt
# Processed: ../data/guideline_data/Novice Mid/18.txt
# Processed: ../data/guideline_data/Advanced Low/15.txt
# Processed: ../data/guideline_data/Advanced Low/14.txt
# Processed: ../data/guideline_data/Advanced Low/16.txt
# Processed: ../data/guideline_data/Advanced Low/17.txt
# Processed: ../data/guideline_data/Advanced Low/13.txt
# Processed: ../data/guideline_data/Advanced Low/12.txt
# Processed: ../data/guideline_data/Advanced Low/10.txt
# Processed: ../data/guideline_data/Advanced Low/11.txt
# Processed: ../data/guideline_data/Advanced Low/9.txt
# Processed: ../data/guideline_data/Advanced Low/8.txt
# Processed: ../data/guideline_data/Advanced Low/5.txt
# Processed: ../data/guideline_data/Advanced Low/4.txt
# Processed: ../data/guideline_data/Advanced Low/6.txt
# Processed: ../data/guideline_data/Advanced Low/7.txt
# Processed: ../data/guideline_data/Advanced Low/3.txt
# Processed: ../data/guideline_data/Advanced Low/2.txt
# Processed: ../data/guideline_data/Advanced Low/0.txt
# Processed: ../data/guideline_data/Advanced Low/1.txt
# Processed: ../data/guideline_data/Advanced Low/19.txt
# Processed: ../data/guideline_data/Advanced Low/18.txt
# Processed: ../data/guideline_data/Novice Low/15.txt
# Processed: ../data/guideline_data/Novice Low/14.txt
# Processed: ../data/guideline_data/Novice Low/16.txt
# Processed: ../data/guideline_data/Novice Low/17.txt
# Processed: ../data/guideline_data/Novice Low/13.txt
# Processed: ../data/guideline_data/Novice Low/12.txt
# Processed: ../data/guideline_data/Novice Low/10.txt
# Processed: ../data/guideline_data/Novice Low/11.txt
# Processed: ../data/guideline_data/Novice Low/9.txt
# Processed: ../data/guideline_data/Novice Low/8.txt
# Processed: ../data/guideline_data/Novice Low/5.txt
# Processed: ../data/guideline_data/Novice Low/4.txt
# Processed: ../data/guideline_data/Novice Low/6.txt
# Processed: ../data/guideline_data/Novice Low/7.txt
# Processed: ../data/guideline_data/Novice Low/3.txt
# Processed: ../data/guideline_data/Novice Low/2.txt
# Processed: ../data/guideline_data/Novice Low/0.txt
# Processed: ../data/guideline_data/Novice Low/1.txt
# Processed: ../data/guideline_data/Novice Low/19.txt
# Processed: ../data/guideline_data/Novice Low/18.txt
# Processed: ../data/guideline_data/Distinguished/15.txt
# Processed: ../data/guideline_data/Distinguished/14.txt
# Processed: ../data/guideline_data/Distinguished/16.txt
# Processed: ../data/guideline_data/Distinguished/17.txt
# Processed: ../data/guideline_data/Distinguished/13.txt
# Processed: ../data/guideline_data/Distinguished/12.txt
# Processed: ../data/guideline_data/Distinguished/10.txt
# Processed: ../data/guideline_data/Distinguished/11.txt
# Processed: ../data/guideline_data/Distinguished/9.txt
# Processed: ../data/guideline_data/Distinguished/8.txt
# Processed: ../data/guideline_data/Distinguished/5.txt
# Processed: ../data/guideline_data/Distinguished/4.txt
# Processed: ../data/guideline_data/Distinguished/6.txt
# Processed: ../data/guideline_data/Distinguished/7.txt
# Processed: ../data/guideline_data/Distinguished/3.txt
# Processed: ../data/guideline_data/Distinguished/2.txt
# Processed: ../data/guideline_data/Distinguished/0.txt
# Processed: ../data/guideline_data/Distinguished/1.txt
# Processed: ../data/guideline_data/Distinguished/19.txt
# Processed: ../data/guideline_data/Distinguished/18.txt

# %%
def splitToSingleLines(filePath):
    with open(filePath, 'r') as file:
        content = file.read()

    fileNum = int(filePath.split('/')[-1].split('.')[0])

    lines = content.split('\n')
    i = 0
    for line in lines:
        # Remove the leading "*. "
        line = line.strip()[3:]
        itemFileName = f"item{fileNum * 5 + i}.txt"

        itemFilePath = os.path.join(os.path.dirname(filePath), itemFileName)
        with open(itemFilePath, 'w') as itemFile:
            itemFile.write(line)

        print(f"Created: {itemFilePath}")
        i += 1

def processDir(dirPath):
    for root, dirs, files in os.walk(dirPath):
        for filename in files:
            if filename.endswith('.txt'):
                file_path = os.path.join(root, filename)
                splitToSingleLines(file_path)
                print(f"Processed: {file_path}")

folder_path = '../data/guideline_data'
processDir(folder_path)
# Out:
# Created: ../data/guideline_data/Advanced High/item75.txt
# Created: ../data/guideline_data/Advanced High/item76.txt
# Created: ../data/guideline_data/Advanced High/item77.txt
# Created: ../data/guideline_data/Advanced High/item78.txt
# Created: ../data/guideline_data/Advanced High/item79.txt
# Processed: ../data/guideline_data/Advanced High/15.txt
# Created: ../data/guideline_data/Advanced High/item70.txt
# Created: ../data/guideline_data/Advanced High/item71.txt
# Created: ../data/guideline_data/Advanced High/item72.txt
# Created: ../data/guideline_data/Advanced High/item73.txt
# Created: ../data/guideline_data/Advanced High/item74.txt
# Processed: ../data/guideline_data/Advanced High/14.txt
# Created: ../data/guideline_data/Advanced High/item80.txt
# Created: ../data/guideline_data/Advanced High/item81.txt
# Created: ../data/guideline_data/Advanced High/item82.txt
# Created: ../data/guideline_data/Advanced High/item83.txt
# Created: ../data/guideline_data/Advanced High/item84.txt
# Processed: ../data/guideline_data/Advanced High/16.txt
# Created: ../data/guideline_data/Advanced High/item85.txt
# Created: ../data/guideline_data/Advanced High/item86.txt
# Created: ../data/guideline_data/Advanced High/item87.txt
# Created: ../data/guideline_data/Advanced High/item88.txt
# Created: ../data/guideline_data/Advanced High/item89.txt
# Processed: ../data/guideline_data/Advanced High/17.txt
# Created: ../data/guideline_data/Advanced High/item65.txt
# Created: ../data/guideline_data/Advanced High/item66.txt
# Created: ../data/guideline_data/Advanced High/item67.txt
# Created: ../data/guideline_data/Advanced High/item68.txt
# Created: ../data/guideline_data/Advanced High/item69.txt
# Processed: ../data/guideline_data/Advanced High/13.txt
# Created: ../data/guideline_data/Advanced High/item60.txt
# Created: ../data/guideline_data/Advanced High/item61.txt
# Created: ../data/guideline_data/Advanced High/item62.txt
# Created: ../data/guideline_data/Advanced High/item63.txt
# Created: ../data/guideline_data/Advanced High/item64.txt
# Processed: ../data/guideline_data/Advanced High/12.txt
# Created: ../data/guideline_data/Advanced High/item50.txt
# Created: ../data/guideline_data/Advanced High/item51.txt
# Created: ../data/guideline_data/Advanced High/item52.txt
# Created: ../data/guideline_data/Advanced High/item53.txt
# Created: ../data/guideline_data/Advanced High/item54.txt
# Processed: ../data/guideline_data/Advanced High/10.txt
# Created: ../data/guideline_data/Advanced High/item55.txt
# Created: ../data/guideline_data/Advanced High/item56.txt
# Created: ../data/guideline_data/Advanced High/item57.txt
# Created: ../data/guideline_data/Advanced High/item58.txt
# Created: ../data/guideline_data/Advanced High/item59.txt
# Created: ../data/guideline_data/Advanced High/item60.txt
# Created: ../data/guideline_data/Advanced High/item61.txt
# Created: ../data/guideline_data/Advanced High/item62.txt
# Created: ../data/guideline_data/Advanced High/item63.txt
# Created: ../data/guideline_data/Advanced High/item64.txt
# Processed: ../data/guideline_data/Advanced High/11.txt
# Created: ../data/guideline_data/Advanced High/item45.txt
# Created: ../data/guideline_data/Advanced High/item46.txt
# Created: ../data/guideline_data/Advanced High/item47.txt
# Created: ../data/guideline_data/Advanced High/item48.txt
# Created: ../data/guideline_data/Advanced High/item49.txt
# Processed: ../data/guideline_data/Advanced High/9.txt
# Created: ../data/guideline_data/Advanced High/item40.txt
# Created: ../data/guideline_data/Advanced High/item41.txt
# Created: ../data/guideline_data/Advanced High/item42.txt
# Created: ../data/guideline_data/Advanced High/item43.txt
# Created: ../data/guideline_data/Advanced High/item44.txt
# Processed: ../data/guideline_data/Advanced High/8.txt
# Created: ../data/guideline_data/Advanced High/item25.txt
# Created: ../data/guideline_data/Advanced High/item26.txt
# Created: ../data/guideline_data/Advanced High/item27.txt
# Created: ../data/guideline_data/Advanced High/item28.txt
# Created: ../data/guideline_data/Advanced High/item29.txt
# Processed: ../data/guideline_data/Advanced High/5.txt
# Created: ../data/guideline_data/Advanced High/item20.txt
# Created: ../data/guideline_data/Advanced High/item21.txt
# Created: ../data/guideline_data/Advanced High/item22.txt
# Created: ../data/guideline_data/Advanced High/item23.txt
# Created: ../data/guideline_data/Advanced High/item24.txt
# Processed: ../data/guideline_data/Advanced High/4.txt
# Created: ../data/guideline_data/Advanced High/item30.txt
# Created: ../data/guideline_data/Advanced High/item31.txt
# Created: ../data/guideline_data/Advanced High/item32.txt
# Created: ../data/guideline_data/Advanced High/item33.txt
# Created: ../data/guideline_data/Advanced High/item34.txt
# Processed: ../data/guideline_data/Advanced High/6.txt
# Created: ../data/guideline_data/Advanced High/item35.txt
# Created: ../data/guideline_data/Advanced High/item36.txt
# Created: ../data/guideline_data/Advanced High/item37.txt
# Created: ../data/guideline_data/Advanced High/item38.txt
# Created: ../data/guideline_data/Advanced High/item39.txt
# Processed: ../data/guideline_data/Advanced High/7.txt
# Created: ../data/guideline_data/Advanced High/item15.txt
# Created: ../data/guideline_data/Advanced High/item16.txt
# Created: ../data/guideline_data/Advanced High/item17.txt
# Created: ../data/guideline_data/Advanced High/item18.txt
# Created: ../data/guideline_data/Advanced High/item19.txt
# Processed: ../data/guideline_data/Advanced High/3.txt
# Created: ../data/guideline_data/Advanced High/item10.txt
# Created: ../data/guideline_data/Advanced High/item11.txt
# Created: ../data/guideline_data/Advanced High/item12.txt
# Created: ../data/guideline_data/Advanced High/item13.txt
# Created: ../data/guideline_data/Advanced High/item14.txt
# Processed: ../data/guideline_data/Advanced High/2.txt
# Created: ../data/guideline_data/Advanced High/item0.txt
# Created: ../data/guideline_data/Advanced High/item1.txt
# Created: ../data/guideline_data/Advanced High/item2.txt
# Created: ../data/guideline_data/Advanced High/item3.txt
# Created: ../data/guideline_data/Advanced High/item4.txt
# Processed: ../data/guideline_data/Advanced High/0.txt
# Created: ../data/guideline_data/Advanced High/item5.txt
# Created: ../data/guideline_data/Advanced High/item6.txt
# Created: ../data/guideline_data/Advanced High/item7.txt
# Created: ../data/guideline_data/Advanced High/item8.txt
# Created: ../data/guideline_data/Advanced High/item9.txt
# Processed: ../data/guideline_data/Advanced High/1.txt
# Created: ../data/guideline_data/Advanced High/item95.txt
# Created: ../data/guideline_data/Advanced High/item96.txt
# Created: ../data/guideline_data/Advanced High/item97.txt
# Created: ../data/guideline_data/Advanced High/item98.txt
# Created: ../data/guideline_data/Advanced High/item99.txt
# Processed: ../data/guideline_data/Advanced High/19.txt
# Created: ../data/guideline_data/Advanced High/item90.txt
# Created: ../data/guideline_data/Advanced High/item91.txt
# Created: ../data/guideline_data/Advanced High/item92.txt
# Created: ../data/guideline_data/Advanced High/item93.txt
# Created: ../data/guideline_data/Advanced High/item94.txt
# Processed: ../data/guideline_data/Advanced High/18.txt
# Created: ../data/guideline_data/Intermediate High/item75.txt
# Created: ../data/guideline_data/Intermediate High/item76.txt
# Created: ../data/guideline_data/Intermediate High/item77.txt
# Created: ../data/guideline_data/Intermediate High/item78.txt
# Created: ../data/guideline_data/Intermediate High/item79.txt
# Processed: ../data/guideline_data/Intermediate High/15.txt
# Created: ../data/guideline_data/Intermediate High/item70.txt
# Created: ../data/guideline_data/Intermediate High/item71.txt
# Created: ../data/guideline_data/Intermediate High/item72.txt
# Created: ../data/guideline_data/Intermediate High/item73.txt
# Created: ../data/guideline_data/Intermediate High/item74.txt
# Processed: ../data/guideline_data/Intermediate High/14.txt
# Created: ../data/guideline_data/Intermediate High/item80.txt
# Created: ../data/guideline_data/Intermediate High/item81.txt
# Created: ../data/guideline_data/Intermediate High/item82.txt
# Created: ../data/guideline_data/Intermediate High/item83.txt
# Created: ../data/guideline_data/Intermediate High/item84.txt
# Processed: ../data/guideline_data/Intermediate High/16.txt
# Created: ../data/guideline_data/Intermediate High/item85.txt
# Created: ../data/guideline_data/Intermediate High/item86.txt
# Created: ../data/guideline_data/Intermediate High/item87.txt
# Created: ../data/guideline_data/Intermediate High/item88.txt
# Created: ../data/guideline_data/Intermediate High/item89.txt
# Processed: ../data/guideline_data/Intermediate High/17.txt
# Created: ../data/guideline_data/Intermediate High/item65.txt
# Created: ../data/guideline_data/Intermediate High/item66.txt
# Created: ../data/guideline_data/Intermediate High/item67.txt
# Created: ../data/guideline_data/Intermediate High/item68.txt
# Created: ../data/guideline_data/Intermediate High/item69.txt
# Processed: ../data/guideline_data/Intermediate High/13.txt
# Created: ../data/guideline_data/Intermediate High/item60.txt
# Created: ../data/guideline_data/Intermediate High/item61.txt
# Created: ../data/guideline_data/Intermediate High/item62.txt
# Created: ../data/guideline_data/Intermediate High/item63.txt
# Created: ../data/guideline_data/Intermediate High/item64.txt
# Processed: ../data/guideline_data/Intermediate High/12.txt
# Created: ../data/guideline_data/Intermediate High/item50.txt
# Created: ../data/guideline_data/Intermediate High/item51.txt
# Created: ../data/guideline_data/Intermediate High/item52.txt
# Created: ../data/guideline_data/Intermediate High/item53.txt
# Created: ../data/guideline_data/Intermediate High/item54.txt
# Processed: ../data/guideline_data/Intermediate High/10.txt
# Created: ../data/guideline_data/Intermediate High/item55.txt
# Created: ../data/guideline_data/Intermediate High/item56.txt
# Created: ../data/guideline_data/Intermediate High/item57.txt
# Created: ../data/guideline_data/Intermediate High/item58.txt
# Created: ../data/guideline_data/Intermediate High/item59.txt
# Processed: ../data/guideline_data/Intermediate High/11.txt
# Created: ../data/guideline_data/Intermediate High/item45.txt
# Created: ../data/guideline_data/Intermediate High/item46.txt
# Created: ../data/guideline_data/Intermediate High/item47.txt
# Created: ../data/guideline_data/Intermediate High/item48.txt
# Created: ../data/guideline_data/Intermediate High/item49.txt
# Processed: ../data/guideline_data/Intermediate High/9.txt
# Created: ../data/guideline_data/Intermediate High/item40.txt
# Created: ../data/guideline_data/Intermediate High/item41.txt
# Created: ../data/guideline_data/Intermediate High/item42.txt
# Created: ../data/guideline_data/Intermediate High/item43.txt
# Created: ../data/guideline_data/Intermediate High/item44.txt
# Processed: ../data/guideline_data/Intermediate High/8.txt
# Created: ../data/guideline_data/Intermediate High/item25.txt
# Created: ../data/guideline_data/Intermediate High/item26.txt
# Created: ../data/guideline_data/Intermediate High/item27.txt
# Created: ../data/guideline_data/Intermediate High/item28.txt
# Created: ../data/guideline_data/Intermediate High/item29.txt
# Processed: ../data/guideline_data/Intermediate High/5.txt
# Created: ../data/guideline_data/Intermediate High/item20.txt
# Created: ../data/guideline_data/Intermediate High/item21.txt
# Created: ../data/guideline_data/Intermediate High/item22.txt
# Created: ../data/guideline_data/Intermediate High/item23.txt
# Created: ../data/guideline_data/Intermediate High/item24.txt
# Processed: ../data/guideline_data/Intermediate High/4.txt
# Created: ../data/guideline_data/Intermediate High/item30.txt
# Created: ../data/guideline_data/Intermediate High/item31.txt
# Created: ../data/guideline_data/Intermediate High/item32.txt
# Created: ../data/guideline_data/Intermediate High/item33.txt
# Created: ../data/guideline_data/Intermediate High/item34.txt
# Processed: ../data/guideline_data/Intermediate High/6.txt
# Created: ../data/guideline_data/Intermediate High/item35.txt
# Created: ../data/guideline_data/Intermediate High/item36.txt
# Created: ../data/guideline_data/Intermediate High/item37.txt
# Created: ../data/guideline_data/Intermediate High/item38.txt
# Created: ../data/guideline_data/Intermediate High/item39.txt
# Processed: ../data/guideline_data/Intermediate High/7.txt
# Created: ../data/guideline_data/Intermediate High/item15.txt
# Created: ../data/guideline_data/Intermediate High/item16.txt
# Created: ../data/guideline_data/Intermediate High/item17.txt
# Created: ../data/guideline_data/Intermediate High/item18.txt
# Created: ../data/guideline_data/Intermediate High/item19.txt
# Processed: ../data/guideline_data/Intermediate High/3.txt
# Created: ../data/guideline_data/Intermediate High/item10.txt
# Created: ../data/guideline_data/Intermediate High/item11.txt
# Created: ../data/guideline_data/Intermediate High/item12.txt
# Created: ../data/guideline_data/Intermediate High/item13.txt
# Created: ../data/guideline_data/Intermediate High/item14.txt
# Processed: ../data/guideline_data/Intermediate High/2.txt
# Created: ../data/guideline_data/Intermediate High/item0.txt
# Created: ../data/guideline_data/Intermediate High/item1.txt
# Created: ../data/guideline_data/Intermediate High/item2.txt
# Created: ../data/guideline_data/Intermediate High/item3.txt
# Created: ../data/guideline_data/Intermediate High/item4.txt
# Processed: ../data/guideline_data/Intermediate High/0.txt
# Created: ../data/guideline_data/Intermediate High/item5.txt
# Created: ../data/guideline_data/Intermediate High/item6.txt
# Created: ../data/guideline_data/Intermediate High/item7.txt
# Created: ../data/guideline_data/Intermediate High/item8.txt
# Created: ../data/guideline_data/Intermediate High/item9.txt
# Processed: ../data/guideline_data/Intermediate High/1.txt
# Created: ../data/guideline_data/Intermediate High/item95.txt
# Created: ../data/guideline_data/Intermediate High/item96.txt
# Created: ../data/guideline_data/Intermediate High/item97.txt
# Created: ../data/guideline_data/Intermediate High/item98.txt
# Created: ../data/guideline_data/Intermediate High/item99.txt
# Processed: ../data/guideline_data/Intermediate High/19.txt
# Created: ../data/guideline_data/Intermediate High/item90.txt
# Created: ../data/guideline_data/Intermediate High/item91.txt
# Created: ../data/guideline_data/Intermediate High/item92.txt
# Created: ../data/guideline_data/Intermediate High/item93.txt
# Created: ../data/guideline_data/Intermediate High/item94.txt
# Processed: ../data/guideline_data/Intermediate High/18.txt
# Created: ../data/guideline_data/Intermediate Mid/item75.txt
# Created: ../data/guideline_data/Intermediate Mid/item76.txt
# Created: ../data/guideline_data/Intermediate Mid/item77.txt
# Created: ../data/guideline_data/Intermediate Mid/item78.txt
# Created: ../data/guideline_data/Intermediate Mid/item79.txt
# Processed: ../data/guideline_data/Intermediate Mid/15.txt
# Created: ../data/guideline_data/Intermediate Mid/item70.txt
# Created: ../data/guideline_data/Intermediate Mid/item71.txt
# Created: ../data/guideline_data/Intermediate Mid/item72.txt
# Created: ../data/guideline_data/Intermediate Mid/item73.txt
# Created: ../data/guideline_data/Intermediate Mid/item74.txt
# Processed: ../data/guideline_data/Intermediate Mid/14.txt
# Created: ../data/guideline_data/Intermediate Mid/item80.txt
# Created: ../data/guideline_data/Intermediate Mid/item81.txt
# Created: ../data/guideline_data/Intermediate Mid/item82.txt
# Created: ../data/guideline_data/Intermediate Mid/item83.txt
# Created: ../data/guideline_data/Intermediate Mid/item84.txt
# Processed: ../data/guideline_data/Intermediate Mid/16.txt
# Created: ../data/guideline_data/Intermediate Mid/item85.txt
# Created: ../data/guideline_data/Intermediate Mid/item86.txt
# Created: ../data/guideline_data/Intermediate Mid/item87.txt
# Created: ../data/guideline_data/Intermediate Mid/item88.txt
# Created: ../data/guideline_data/Intermediate Mid/item89.txt
# Processed: ../data/guideline_data/Intermediate Mid/17.txt
# Created: ../data/guideline_data/Intermediate Mid/item65.txt
# Created: ../data/guideline_data/Intermediate Mid/item66.txt
# Created: ../data/guideline_data/Intermediate Mid/item67.txt
# Created: ../data/guideline_data/Intermediate Mid/item68.txt
# Created: ../data/guideline_data/Intermediate Mid/item69.txt
# Processed: ../data/guideline_data/Intermediate Mid/13.txt
# Created: ../data/guideline_data/Intermediate Mid/item60.txt
# Created: ../data/guideline_data/Intermediate Mid/item61.txt
# Created: ../data/guideline_data/Intermediate Mid/item62.txt
# Created: ../data/guideline_data/Intermediate Mid/item63.txt
# Created: ../data/guideline_data/Intermediate Mid/item64.txt
# Processed: ../data/guideline_data/Intermediate Mid/12.txt
# Created: ../data/guideline_data/Intermediate Mid/item50.txt
# Created: ../data/guideline_data/Intermediate Mid/item51.txt
# Created: ../data/guideline_data/Intermediate Mid/item52.txt
# Created: ../data/guideline_data/Intermediate Mid/item53.txt
# Created: ../data/guideline_data/Intermediate Mid/item54.txt
# Processed: ../data/guideline_data/Intermediate Mid/10.txt
# Created: ../data/guideline_data/Intermediate Mid/item55.txt
# Created: ../data/guideline_data/Intermediate Mid/item56.txt
# Created: ../data/guideline_data/Intermediate Mid/item57.txt
# Created: ../data/guideline_data/Intermediate Mid/item58.txt
# Created: ../data/guideline_data/Intermediate Mid/item59.txt
# Processed: ../data/guideline_data/Intermediate Mid/11.txt
# Created: ../data/guideline_data/Intermediate Mid/item45.txt
# Created: ../data/guideline_data/Intermediate Mid/item46.txt
# Created: ../data/guideline_data/Intermediate Mid/item47.txt
# Created: ../data/guideline_data/Intermediate Mid/item48.txt
# Created: ../data/guideline_data/Intermediate Mid/item49.txt
# Processed: ../data/guideline_data/Intermediate Mid/9.txt
# Created: ../data/guideline_data/Intermediate Mid/item40.txt
# Created: ../data/guideline_data/Intermediate Mid/item41.txt
# Created: ../data/guideline_data/Intermediate Mid/item42.txt
# Created: ../data/guideline_data/Intermediate Mid/item43.txt
# Created: ../data/guideline_data/Intermediate Mid/item44.txt
# Processed: ../data/guideline_data/Intermediate Mid/8.txt
# Created: ../data/guideline_data/Intermediate Mid/item25.txt
# Created: ../data/guideline_data/Intermediate Mid/item26.txt
# Created: ../data/guideline_data/Intermediate Mid/item27.txt
# Created: ../data/guideline_data/Intermediate Mid/item28.txt
# Created: ../data/guideline_data/Intermediate Mid/item29.txt
# Processed: ../data/guideline_data/Intermediate Mid/5.txt
# Created: ../data/guideline_data/Intermediate Mid/item20.txt
# Created: ../data/guideline_data/Intermediate Mid/item21.txt
# Created: ../data/guideline_data/Intermediate Mid/item22.txt
# Created: ../data/guideline_data/Intermediate Mid/item23.txt
# Created: ../data/guideline_data/Intermediate Mid/item24.txt
# Processed: ../data/guideline_data/Intermediate Mid/4.txt
# Created: ../data/guideline_data/Intermediate Mid/item30.txt
# Created: ../data/guideline_data/Intermediate Mid/item31.txt
# Created: ../data/guideline_data/Intermediate Mid/item32.txt
# Created: ../data/guideline_data/Intermediate Mid/item33.txt
# Created: ../data/guideline_data/Intermediate Mid/item34.txt
# Processed: ../data/guideline_data/Intermediate Mid/6.txt
# Created: ../data/guideline_data/Intermediate Mid/item35.txt
# Created: ../data/guideline_data/Intermediate Mid/item36.txt
# Created: ../data/guideline_data/Intermediate Mid/item37.txt
# Created: ../data/guideline_data/Intermediate Mid/item38.txt
# Created: ../data/guideline_data/Intermediate Mid/item39.txt
# Processed: ../data/guideline_data/Intermediate Mid/7.txt
# Created: ../data/guideline_data/Intermediate Mid/item15.txt
# Created: ../data/guideline_data/Intermediate Mid/item16.txt
# Created: ../data/guideline_data/Intermediate Mid/item17.txt
# Created: ../data/guideline_data/Intermediate Mid/item18.txt
# Created: ../data/guideline_data/Intermediate Mid/item19.txt
# Processed: ../data/guideline_data/Intermediate Mid/3.txt
# Created: ../data/guideline_data/Intermediate Mid/item10.txt
# Created: ../data/guideline_data/Intermediate Mid/item11.txt
# Created: ../data/guideline_data/Intermediate Mid/item12.txt
# Created: ../data/guideline_data/Intermediate Mid/item13.txt
# Created: ../data/guideline_data/Intermediate Mid/item14.txt
# Processed: ../data/guideline_data/Intermediate Mid/2.txt
# Created: ../data/guideline_data/Intermediate Mid/item0.txt
# Created: ../data/guideline_data/Intermediate Mid/item1.txt
# Created: ../data/guideline_data/Intermediate Mid/item2.txt
# Created: ../data/guideline_data/Intermediate Mid/item3.txt
# Created: ../data/guideline_data/Intermediate Mid/item4.txt
# Processed: ../data/guideline_data/Intermediate Mid/0.txt
# Created: ../data/guideline_data/Intermediate Mid/item5.txt
# Created: ../data/guideline_data/Intermediate Mid/item6.txt
# Created: ../data/guideline_data/Intermediate Mid/item7.txt
# Created: ../data/guideline_data/Intermediate Mid/item8.txt
# Created: ../data/guideline_data/Intermediate Mid/item9.txt
# Processed: ../data/guideline_data/Intermediate Mid/1.txt
# Created: ../data/guideline_data/Intermediate Mid/item95.txt
# Created: ../data/guideline_data/Intermediate Mid/item96.txt
# Created: ../data/guideline_data/Intermediate Mid/item97.txt
# Created: ../data/guideline_data/Intermediate Mid/item98.txt
# Created: ../data/guideline_data/Intermediate Mid/item99.txt
# Processed: ../data/guideline_data/Intermediate Mid/19.txt
# Created: ../data/guideline_data/Intermediate Mid/item90.txt
# Created: ../data/guideline_data/Intermediate Mid/item91.txt
# Created: ../data/guideline_data/Intermediate Mid/item92.txt
# Created: ../data/guideline_data/Intermediate Mid/item93.txt
# Created: ../data/guideline_data/Intermediate Mid/item94.txt
# Processed: ../data/guideline_data/Intermediate Mid/18.txt
# Created: ../data/guideline_data/Intermediate Low/item75.txt
# Created: ../data/guideline_data/Intermediate Low/item76.txt
# Created: ../data/guideline_data/Intermediate Low/item77.txt
# Created: ../data/guideline_data/Intermediate Low/item78.txt
# Created: ../data/guideline_data/Intermediate Low/item79.txt
# Processed: ../data/guideline_data/Intermediate Low/15.txt
# Created: ../data/guideline_data/Intermediate Low/item70.txt
# Created: ../data/guideline_data/Intermediate Low/item71.txt
# Created: ../data/guideline_data/Intermediate Low/item72.txt
# Created: ../data/guideline_data/Intermediate Low/item73.txt
# Created: ../data/guideline_data/Intermediate Low/item74.txt
# Processed: ../data/guideline_data/Intermediate Low/14.txt
# Created: ../data/guideline_data/Intermediate Low/item80.txt
# Created: ../data/guideline_data/Intermediate Low/item81.txt
# Created: ../data/guideline_data/Intermediate Low/item82.txt
# Created: ../data/guideline_data/Intermediate Low/item83.txt
# Created: ../data/guideline_data/Intermediate Low/item84.txt
# Processed: ../data/guideline_data/Intermediate Low/16.txt
# Created: ../data/guideline_data/Intermediate Low/item85.txt
# Created: ../data/guideline_data/Intermediate Low/item86.txt
# Created: ../data/guideline_data/Intermediate Low/item87.txt
# Created: ../data/guideline_data/Intermediate Low/item88.txt
# Created: ../data/guideline_data/Intermediate Low/item89.txt
# Processed: ../data/guideline_data/Intermediate Low/17.txt
# Created: ../data/guideline_data/Intermediate Low/item65.txt
# Created: ../data/guideline_data/Intermediate Low/item66.txt
# Created: ../data/guideline_data/Intermediate Low/item67.txt
# Created: ../data/guideline_data/Intermediate Low/item68.txt
# Created: ../data/guideline_data/Intermediate Low/item69.txt
# Processed: ../data/guideline_data/Intermediate Low/13.txt
# Created: ../data/guideline_data/Intermediate Low/item60.txt
# Created: ../data/guideline_data/Intermediate Low/item61.txt
# Created: ../data/guideline_data/Intermediate Low/item62.txt
# Created: ../data/guideline_data/Intermediate Low/item63.txt
# Created: ../data/guideline_data/Intermediate Low/item64.txt
# Processed: ../data/guideline_data/Intermediate Low/12.txt
# Created: ../data/guideline_data/Intermediate Low/item50.txt
# Created: ../data/guideline_data/Intermediate Low/item51.txt
# Created: ../data/guideline_data/Intermediate Low/item52.txt
# Created: ../data/guideline_data/Intermediate Low/item53.txt
# Created: ../data/guideline_data/Intermediate Low/item54.txt
# Processed: ../data/guideline_data/Intermediate Low/10.txt
# Created: ../data/guideline_data/Intermediate Low/item55.txt
# Created: ../data/guideline_data/Intermediate Low/item56.txt
# Created: ../data/guideline_data/Intermediate Low/item57.txt
# Created: ../data/guideline_data/Intermediate Low/item58.txt
# Created: ../data/guideline_data/Intermediate Low/item59.txt
# Processed: ../data/guideline_data/Intermediate Low/11.txt
# Created: ../data/guideline_data/Intermediate Low/item45.txt
# Created: ../data/guideline_data/Intermediate Low/item46.txt
# Created: ../data/guideline_data/Intermediate Low/item47.txt
# Created: ../data/guideline_data/Intermediate Low/item48.txt
# Created: ../data/guideline_data/Intermediate Low/item49.txt
# Processed: ../data/guideline_data/Intermediate Low/9.txt
# Created: ../data/guideline_data/Intermediate Low/item40.txt
# Created: ../data/guideline_data/Intermediate Low/item41.txt
# Created: ../data/guideline_data/Intermediate Low/item42.txt
# Created: ../data/guideline_data/Intermediate Low/item43.txt
# Created: ../data/guideline_data/Intermediate Low/item44.txt
# Processed: ../data/guideline_data/Intermediate Low/8.txt
# Created: ../data/guideline_data/Intermediate Low/item25.txt
# Created: ../data/guideline_data/Intermediate Low/item26.txt
# Created: ../data/guideline_data/Intermediate Low/item27.txt
# Created: ../data/guideline_data/Intermediate Low/item28.txt
# Created: ../data/guideline_data/Intermediate Low/item29.txt
# Processed: ../data/guideline_data/Intermediate Low/5.txt
# Created: ../data/guideline_data/Intermediate Low/item20.txt
# Created: ../data/guideline_data/Intermediate Low/item21.txt
# Created: ../data/guideline_data/Intermediate Low/item22.txt
# Created: ../data/guideline_data/Intermediate Low/item23.txt
# Created: ../data/guideline_data/Intermediate Low/item24.txt
# Processed: ../data/guideline_data/Intermediate Low/4.txt
# Created: ../data/guideline_data/Intermediate Low/item30.txt
# Created: ../data/guideline_data/Intermediate Low/item31.txt
# Created: ../data/guideline_data/Intermediate Low/item32.txt
# Created: ../data/guideline_data/Intermediate Low/item33.txt
# Created: ../data/guideline_data/Intermediate Low/item34.txt
# Processed: ../data/guideline_data/Intermediate Low/6.txt
# Created: ../data/guideline_data/Intermediate Low/item35.txt
# Created: ../data/guideline_data/Intermediate Low/item36.txt
# Created: ../data/guideline_data/Intermediate Low/item37.txt
# Created: ../data/guideline_data/Intermediate Low/item38.txt
# Created: ../data/guideline_data/Intermediate Low/item39.txt
# Processed: ../data/guideline_data/Intermediate Low/7.txt
# Created: ../data/guideline_data/Intermediate Low/item15.txt
# Created: ../data/guideline_data/Intermediate Low/item16.txt
# Created: ../data/guideline_data/Intermediate Low/item17.txt
# Created: ../data/guideline_data/Intermediate Low/item18.txt
# Created: ../data/guideline_data/Intermediate Low/item19.txt
# Processed: ../data/guideline_data/Intermediate Low/3.txt
# Created: ../data/guideline_data/Intermediate Low/item10.txt
# Created: ../data/guideline_data/Intermediate Low/item11.txt
# Created: ../data/guideline_data/Intermediate Low/item12.txt
# Created: ../data/guideline_data/Intermediate Low/item13.txt
# Created: ../data/guideline_data/Intermediate Low/item14.txt
# Processed: ../data/guideline_data/Intermediate Low/2.txt
# Created: ../data/guideline_data/Intermediate Low/item0.txt
# Created: ../data/guideline_data/Intermediate Low/item1.txt
# Created: ../data/guideline_data/Intermediate Low/item2.txt
# Created: ../data/guideline_data/Intermediate Low/item3.txt
# Created: ../data/guideline_data/Intermediate Low/item4.txt
# Processed: ../data/guideline_data/Intermediate Low/0.txt
# Created: ../data/guideline_data/Intermediate Low/item5.txt
# Created: ../data/guideline_data/Intermediate Low/item6.txt
# Created: ../data/guideline_data/Intermediate Low/item7.txt
# Created: ../data/guideline_data/Intermediate Low/item8.txt
# Created: ../data/guideline_data/Intermediate Low/item9.txt
# Processed: ../data/guideline_data/Intermediate Low/1.txt
# Created: ../data/guideline_data/Intermediate Low/item95.txt
# Created: ../data/guideline_data/Intermediate Low/item96.txt
# Created: ../data/guideline_data/Intermediate Low/item97.txt
# Created: ../data/guideline_data/Intermediate Low/item98.txt
# Created: ../data/guideline_data/Intermediate Low/item99.txt
# Processed: ../data/guideline_data/Intermediate Low/19.txt
# Created: ../data/guideline_data/Intermediate Low/item90.txt
# Created: ../data/guideline_data/Intermediate Low/item91.txt
# Created: ../data/guideline_data/Intermediate Low/item92.txt
# Created: ../data/guideline_data/Intermediate Low/item93.txt
# Created: ../data/guideline_data/Intermediate Low/item94.txt
# Processed: ../data/guideline_data/Intermediate Low/18.txt
# Created: ../data/guideline_data/Novice High/item75.txt
# Created: ../data/guideline_data/Novice High/item76.txt
# Created: ../data/guideline_data/Novice High/item77.txt
# Created: ../data/guideline_data/Novice High/item78.txt
# Created: ../data/guideline_data/Novice High/item79.txt
# Processed: ../data/guideline_data/Novice High/15.txt
# Created: ../data/guideline_data/Novice High/item70.txt
# Created: ../data/guideline_data/Novice High/item71.txt
# Created: ../data/guideline_data/Novice High/item72.txt
# Created: ../data/guideline_data/Novice High/item73.txt
# Created: ../data/guideline_data/Novice High/item74.txt
# Processed: ../data/guideline_data/Novice High/14.txt
# Created: ../data/guideline_data/Novice High/item80.txt
# Created: ../data/guideline_data/Novice High/item81.txt
# Created: ../data/guideline_data/Novice High/item82.txt
# Created: ../data/guideline_data/Novice High/item83.txt
# Created: ../data/guideline_data/Novice High/item84.txt
# Processed: ../data/guideline_data/Novice High/16.txt
# Created: ../data/guideline_data/Novice High/item85.txt
# Created: ../data/guideline_data/Novice High/item86.txt
# Created: ../data/guideline_data/Novice High/item87.txt
# Created: ../data/guideline_data/Novice High/item88.txt
# Created: ../data/guideline_data/Novice High/item89.txt
# Processed: ../data/guideline_data/Novice High/17.txt
# Created: ../data/guideline_data/Novice High/item65.txt
# Created: ../data/guideline_data/Novice High/item66.txt
# Created: ../data/guideline_data/Novice High/item67.txt
# Created: ../data/guideline_data/Novice High/item68.txt
# Created: ../data/guideline_data/Novice High/item69.txt
# Processed: ../data/guideline_data/Novice High/13.txt
# Created: ../data/guideline_data/Novice High/item60.txt
# Created: ../data/guideline_data/Novice High/item61.txt
# Created: ../data/guideline_data/Novice High/item62.txt
# Created: ../data/guideline_data/Novice High/item63.txt
# Created: ../data/guideline_data/Novice High/item64.txt
# Processed: ../data/guideline_data/Novice High/12.txt
# Created: ../data/guideline_data/Novice High/item50.txt
# Created: ../data/guideline_data/Novice High/item51.txt
# Created: ../data/guideline_data/Novice High/item52.txt
# Created: ../data/guideline_data/Novice High/item53.txt
# Created: ../data/guideline_data/Novice High/item54.txt
# Processed: ../data/guideline_data/Novice High/10.txt
# Created: ../data/guideline_data/Novice High/item55.txt
# Created: ../data/guideline_data/Novice High/item56.txt
# Created: ../data/guideline_data/Novice High/item57.txt
# Created: ../data/guideline_data/Novice High/item58.txt
# Created: ../data/guideline_data/Novice High/item59.txt
# Processed: ../data/guideline_data/Novice High/11.txt
# Created: ../data/guideline_data/Novice High/item45.txt
# Created: ../data/guideline_data/Novice High/item46.txt
# Created: ../data/guideline_data/Novice High/item47.txt
# Created: ../data/guideline_data/Novice High/item48.txt
# Created: ../data/guideline_data/Novice High/item49.txt
# Processed: ../data/guideline_data/Novice High/9.txt
# Created: ../data/guideline_data/Novice High/item40.txt
# Created: ../data/guideline_data/Novice High/item41.txt
# Created: ../data/guideline_data/Novice High/item42.txt
# Created: ../data/guideline_data/Novice High/item43.txt
# Created: ../data/guideline_data/Novice High/item44.txt
# Processed: ../data/guideline_data/Novice High/8.txt
# Created: ../data/guideline_data/Novice High/item25.txt
# Created: ../data/guideline_data/Novice High/item26.txt
# Created: ../data/guideline_data/Novice High/item27.txt
# Created: ../data/guideline_data/Novice High/item28.txt
# Created: ../data/guideline_data/Novice High/item29.txt
# Processed: ../data/guideline_data/Novice High/5.txt
# Created: ../data/guideline_data/Novice High/item20.txt
# Created: ../data/guideline_data/Novice High/item21.txt
# Created: ../data/guideline_data/Novice High/item22.txt
# Created: ../data/guideline_data/Novice High/item23.txt
# Created: ../data/guideline_data/Novice High/item24.txt
# Processed: ../data/guideline_data/Novice High/4.txt
# Created: ../data/guideline_data/Novice High/item30.txt
# Created: ../data/guideline_data/Novice High/item31.txt
# Created: ../data/guideline_data/Novice High/item32.txt
# Created: ../data/guideline_data/Novice High/item33.txt
# Created: ../data/guideline_data/Novice High/item34.txt
# Processed: ../data/guideline_data/Novice High/6.txt
# Created: ../data/guideline_data/Novice High/item35.txt
# Created: ../data/guideline_data/Novice High/item36.txt
# Created: ../data/guideline_data/Novice High/item37.txt
# Created: ../data/guideline_data/Novice High/item38.txt
# Created: ../data/guideline_data/Novice High/item39.txt
# Processed: ../data/guideline_data/Novice High/7.txt
# Created: ../data/guideline_data/Novice High/item15.txt
# Created: ../data/guideline_data/Novice High/item16.txt
# Created: ../data/guideline_data/Novice High/item17.txt
# Created: ../data/guideline_data/Novice High/item18.txt
# Processed: ../data/guideline_data/Novice High/3.txt
# Created: ../data/guideline_data/Novice High/item10.txt
# Created: ../data/guideline_data/Novice High/item11.txt
# Created: ../data/guideline_data/Novice High/item12.txt
# Created: ../data/guideline_data/Novice High/item13.txt
# Created: ../data/guideline_data/Novice High/item14.txt
# Processed: ../data/guideline_data/Novice High/2.txt
# Created: ../data/guideline_data/Novice High/item0.txt
# Created: ../data/guideline_data/Novice High/item1.txt
# Created: ../data/guideline_data/Novice High/item2.txt
# Created: ../data/guideline_data/Novice High/item3.txt
# Created: ../data/guideline_data/Novice High/item4.txt
# Processed: ../data/guideline_data/Novice High/0.txt
# Created: ../data/guideline_data/Novice High/item5.txt
# Created: ../data/guideline_data/Novice High/item6.txt
# Created: ../data/guideline_data/Novice High/item7.txt
# Created: ../data/guideline_data/Novice High/item8.txt
# Created: ../data/guideline_data/Novice High/item9.txt
# Processed: ../data/guideline_data/Novice High/1.txt
# Created: ../data/guideline_data/Novice High/item95.txt
# Created: ../data/guideline_data/Novice High/item96.txt
# Created: ../data/guideline_data/Novice High/item97.txt
# Created: ../data/guideline_data/Novice High/item98.txt
# Created: ../data/guideline_data/Novice High/item99.txt
# Processed: ../data/guideline_data/Novice High/19.txt
# Created: ../data/guideline_data/Novice High/item90.txt
# Created: ../data/guideline_data/Novice High/item91.txt
# Created: ../data/guideline_data/Novice High/item92.txt
# Created: ../data/guideline_data/Novice High/item93.txt
# Created: ../data/guideline_data/Novice High/item94.txt
# Processed: ../data/guideline_data/Novice High/18.txt
# Created: ../data/guideline_data/Superior/item75.txt
# Created: ../data/guideline_data/Superior/item76.txt
# Created: ../data/guideline_data/Superior/item77.txt
# Created: ../data/guideline_data/Superior/item78.txt
# Created: ../data/guideline_data/Superior/item79.txt
# Processed: ../data/guideline_data/Superior/15.txt
# Created: ../data/guideline_data/Superior/item70.txt
# Created: ../data/guideline_data/Superior/item71.txt
# Created: ../data/guideline_data/Superior/item72.txt
# Created: ../data/guideline_data/Superior/item73.txt
# Created: ../data/guideline_data/Superior/item74.txt
# Processed: ../data/guideline_data/Superior/14.txt
# Created: ../data/guideline_data/Superior/item80.txt
# Created: ../data/guideline_data/Superior/item81.txt
# Created: ../data/guideline_data/Superior/item82.txt
# Created: ../data/guideline_data/Superior/item83.txt
# Created: ../data/guideline_data/Superior/item84.txt
# Processed: ../data/guideline_data/Superior/16.txt
# Created: ../data/guideline_data/Superior/item85.txt
# Created: ../data/guideline_data/Superior/item86.txt
# Created: ../data/guideline_data/Superior/item87.txt
# Created: ../data/guideline_data/Superior/item88.txt
# Created: ../data/guideline_data/Superior/item89.txt
# Processed: ../data/guideline_data/Superior/17.txt
# Created: ../data/guideline_data/Superior/item65.txt
# Created: ../data/guideline_data/Superior/item66.txt
# Created: ../data/guideline_data/Superior/item67.txt
# Created: ../data/guideline_data/Superior/item68.txt
# Created: ../data/guideline_data/Superior/item69.txt
# Processed: ../data/guideline_data/Superior/13.txt
# Created: ../data/guideline_data/Superior/item60.txt
# Created: ../data/guideline_data/Superior/item61.txt
# Created: ../data/guideline_data/Superior/item62.txt
# Created: ../data/guideline_data/Superior/item63.txt
# Created: ../data/guideline_data/Superior/item64.txt
# Processed: ../data/guideline_data/Superior/12.txt
# Created: ../data/guideline_data/Superior/item50.txt
# Created: ../data/guideline_data/Superior/item51.txt
# Created: ../data/guideline_data/Superior/item52.txt
# Created: ../data/guideline_data/Superior/item53.txt
# Created: ../data/guideline_data/Superior/item54.txt
# Processed: ../data/guideline_data/Superior/10.txt
# Created: ../data/guideline_data/Superior/item55.txt
# Created: ../data/guideline_data/Superior/item56.txt
# Created: ../data/guideline_data/Superior/item57.txt
# Created: ../data/guideline_data/Superior/item58.txt
# Created: ../data/guideline_data/Superior/item59.txt
# Processed: ../data/guideline_data/Superior/11.txt
# Created: ../data/guideline_data/Superior/item45.txt
# Created: ../data/guideline_data/Superior/item46.txt
# Created: ../data/guideline_data/Superior/item47.txt
# Created: ../data/guideline_data/Superior/item48.txt
# Created: ../data/guideline_data/Superior/item49.txt
# Processed: ../data/guideline_data/Superior/9.txt
# Created: ../data/guideline_data/Superior/item40.txt
# Created: ../data/guideline_data/Superior/item41.txt
# Created: ../data/guideline_data/Superior/item42.txt
# Created: ../data/guideline_data/Superior/item43.txt
# Created: ../data/guideline_data/Superior/item44.txt
# Processed: ../data/guideline_data/Superior/8.txt
# Created: ../data/guideline_data/Superior/item25.txt
# Created: ../data/guideline_data/Superior/item26.txt
# Created: ../data/guideline_data/Superior/item27.txt
# Created: ../data/guideline_data/Superior/item28.txt
# Created: ../data/guideline_data/Superior/item29.txt
# Processed: ../data/guideline_data/Superior/5.txt
# Created: ../data/guideline_data/Superior/item20.txt
# Created: ../data/guideline_data/Superior/item21.txt
# Created: ../data/guideline_data/Superior/item22.txt
# Created: ../data/guideline_data/Superior/item23.txt
# Created: ../data/guideline_data/Superior/item24.txt
# Processed: ../data/guideline_data/Superior/4.txt
# Created: ../data/guideline_data/Superior/item30.txt
# Created: ../data/guideline_data/Superior/item31.txt
# Created: ../data/guideline_data/Superior/item32.txt
# Created: ../data/guideline_data/Superior/item33.txt
# Created: ../data/guideline_data/Superior/item34.txt
# Processed: ../data/guideline_data/Superior/6.txt
# Created: ../data/guideline_data/Superior/item35.txt
# Created: ../data/guideline_data/Superior/item36.txt
# Created: ../data/guideline_data/Superior/item37.txt
# Created: ../data/guideline_data/Superior/item38.txt
# Created: ../data/guideline_data/Superior/item39.txt
# Processed: ../data/guideline_data/Superior/7.txt
# Created: ../data/guideline_data/Superior/item15.txt
# Created: ../data/guideline_data/Superior/item16.txt
# Created: ../data/guideline_data/Superior/item17.txt
# Created: ../data/guideline_data/Superior/item18.txt
# Created: ../data/guideline_data/Superior/item19.txt
# Processed: ../data/guideline_data/Superior/3.txt
# Created: ../data/guideline_data/Superior/item10.txt
# Created: ../data/guideline_data/Superior/item11.txt
# Created: ../data/guideline_data/Superior/item12.txt
# Created: ../data/guideline_data/Superior/item13.txt
# Created: ../data/guideline_data/Superior/item14.txt
# Processed: ../data/guideline_data/Superior/2.txt
# Created: ../data/guideline_data/Superior/item0.txt
# Created: ../data/guideline_data/Superior/item1.txt
# Created: ../data/guideline_data/Superior/item2.txt
# Created: ../data/guideline_data/Superior/item3.txt
# Created: ../data/guideline_data/Superior/item4.txt
# Processed: ../data/guideline_data/Superior/0.txt
# Created: ../data/guideline_data/Superior/item5.txt
# Created: ../data/guideline_data/Superior/item6.txt
# Created: ../data/guideline_data/Superior/item7.txt
# Created: ../data/guideline_data/Superior/item8.txt
# Created: ../data/guideline_data/Superior/item9.txt
# Processed: ../data/guideline_data/Superior/1.txt
# Created: ../data/guideline_data/Superior/item95.txt
# Created: ../data/guideline_data/Superior/item96.txt
# Created: ../data/guideline_data/Superior/item97.txt
# Created: ../data/guideline_data/Superior/item98.txt
# Created: ../data/guideline_data/Superior/item99.txt
# Processed: ../data/guideline_data/Superior/19.txt
# Created: ../data/guideline_data/Superior/item90.txt
# Created: ../data/guideline_data/Superior/item91.txt
# Created: ../data/guideline_data/Superior/item92.txt
# Created: ../data/guideline_data/Superior/item93.txt
# Created: ../data/guideline_data/Superior/item94.txt
# Processed: ../data/guideline_data/Superior/18.txt
# Created: ../data/guideline_data/Advanced Mid/item75.txt
# Created: ../data/guideline_data/Advanced Mid/item76.txt
# Created: ../data/guideline_data/Advanced Mid/item77.txt
# Created: ../data/guideline_data/Advanced Mid/item78.txt
# Created: ../data/guideline_data/Advanced Mid/item79.txt
# Processed: ../data/guideline_data/Advanced Mid/15.txt
# Created: ../data/guideline_data/Advanced Mid/item70.txt
# Created: ../data/guideline_data/Advanced Mid/item71.txt
# Created: ../data/guideline_data/Advanced Mid/item72.txt
# Created: ../data/guideline_data/Advanced Mid/item73.txt
# Created: ../data/guideline_data/Advanced Mid/item74.txt
# Processed: ../data/guideline_data/Advanced Mid/14.txt
# Created: ../data/guideline_data/Advanced Mid/item80.txt
# Created: ../data/guideline_data/Advanced Mid/item81.txt
# Created: ../data/guideline_data/Advanced Mid/item82.txt
# Created: ../data/guideline_data/Advanced Mid/item83.txt
# Created: ../data/guideline_data/Advanced Mid/item84.txt
# Processed: ../data/guideline_data/Advanced Mid/16.txt
# Created: ../data/guideline_data/Advanced Mid/item85.txt
# Created: ../data/guideline_data/Advanced Mid/item86.txt
# Created: ../data/guideline_data/Advanced Mid/item87.txt
# Created: ../data/guideline_data/Advanced Mid/item88.txt
# Created: ../data/guideline_data/Advanced Mid/item89.txt
# Processed: ../data/guideline_data/Advanced Mid/17.txt
# Created: ../data/guideline_data/Advanced Mid/item65.txt
# Created: ../data/guideline_data/Advanced Mid/item66.txt
# Created: ../data/guideline_data/Advanced Mid/item67.txt
# Created: ../data/guideline_data/Advanced Mid/item68.txt
# Created: ../data/guideline_data/Advanced Mid/item69.txt
# Processed: ../data/guideline_data/Advanced Mid/13.txt
# Created: ../data/guideline_data/Advanced Mid/item60.txt
# Created: ../data/guideline_data/Advanced Mid/item61.txt
# Created: ../data/guideline_data/Advanced Mid/item62.txt
# Created: ../data/guideline_data/Advanced Mid/item63.txt
# Created: ../data/guideline_data/Advanced Mid/item64.txt
# Processed: ../data/guideline_data/Advanced Mid/12.txt
# Created: ../data/guideline_data/Advanced Mid/item50.txt
# Created: ../data/guideline_data/Advanced Mid/item51.txt
# Created: ../data/guideline_data/Advanced Mid/item52.txt
# Created: ../data/guideline_data/Advanced Mid/item53.txt
# Created: ../data/guideline_data/Advanced Mid/item54.txt
# Processed: ../data/guideline_data/Advanced Mid/10.txt
# Created: ../data/guideline_data/Advanced Mid/item55.txt
# Created: ../data/guideline_data/Advanced Mid/item56.txt
# Created: ../data/guideline_data/Advanced Mid/item57.txt
# Created: ../data/guideline_data/Advanced Mid/item58.txt
# Created: ../data/guideline_data/Advanced Mid/item59.txt
# Processed: ../data/guideline_data/Advanced Mid/11.txt
# Created: ../data/guideline_data/Advanced Mid/item45.txt
# Created: ../data/guideline_data/Advanced Mid/item46.txt
# Created: ../data/guideline_data/Advanced Mid/item47.txt
# Created: ../data/guideline_data/Advanced Mid/item48.txt
# Created: ../data/guideline_data/Advanced Mid/item49.txt
# Processed: ../data/guideline_data/Advanced Mid/9.txt
# Created: ../data/guideline_data/Advanced Mid/item40.txt
# Created: ../data/guideline_data/Advanced Mid/item41.txt
# Created: ../data/guideline_data/Advanced Mid/item42.txt
# Created: ../data/guideline_data/Advanced Mid/item43.txt
# Created: ../data/guideline_data/Advanced Mid/item44.txt
# Processed: ../data/guideline_data/Advanced Mid/8.txt
# Created: ../data/guideline_data/Advanced Mid/item25.txt
# Created: ../data/guideline_data/Advanced Mid/item26.txt
# Created: ../data/guideline_data/Advanced Mid/item27.txt
# Created: ../data/guideline_data/Advanced Mid/item28.txt
# Created: ../data/guideline_data/Advanced Mid/item29.txt
# Processed: ../data/guideline_data/Advanced Mid/5.txt
# Created: ../data/guideline_data/Advanced Mid/item20.txt
# Created: ../data/guideline_data/Advanced Mid/item21.txt
# Created: ../data/guideline_data/Advanced Mid/item22.txt
# Created: ../data/guideline_data/Advanced Mid/item23.txt
# Created: ../data/guideline_data/Advanced Mid/item24.txt
# Processed: ../data/guideline_data/Advanced Mid/4.txt
# Created: ../data/guideline_data/Advanced Mid/item30.txt
# Created: ../data/guideline_data/Advanced Mid/item31.txt
# Created: ../data/guideline_data/Advanced Mid/item32.txt
# Created: ../data/guideline_data/Advanced Mid/item33.txt
# Created: ../data/guideline_data/Advanced Mid/item34.txt
# Processed: ../data/guideline_data/Advanced Mid/6.txt
# Created: ../data/guideline_data/Advanced Mid/item35.txt
# Created: ../data/guideline_data/Advanced Mid/item36.txt
# Created: ../data/guideline_data/Advanced Mid/item37.txt
# Created: ../data/guideline_data/Advanced Mid/item38.txt
# Created: ../data/guideline_data/Advanced Mid/item39.txt
# Processed: ../data/guideline_data/Advanced Mid/7.txt
# Created: ../data/guideline_data/Advanced Mid/item15.txt
# Created: ../data/guideline_data/Advanced Mid/item16.txt
# Created: ../data/guideline_data/Advanced Mid/item17.txt
# Created: ../data/guideline_data/Advanced Mid/item18.txt
# Created: ../data/guideline_data/Advanced Mid/item19.txt
# Processed: ../data/guideline_data/Advanced Mid/3.txt
# Created: ../data/guideline_data/Advanced Mid/item10.txt
# Created: ../data/guideline_data/Advanced Mid/item11.txt
# Created: ../data/guideline_data/Advanced Mid/item12.txt
# Created: ../data/guideline_data/Advanced Mid/item13.txt
# Created: ../data/guideline_data/Advanced Mid/item14.txt
# Processed: ../data/guideline_data/Advanced Mid/2.txt
# Created: ../data/guideline_data/Advanced Mid/item0.txt
# Created: ../data/guideline_data/Advanced Mid/item1.txt
# Created: ../data/guideline_data/Advanced Mid/item2.txt
# Created: ../data/guideline_data/Advanced Mid/item3.txt
# Created: ../data/guideline_data/Advanced Mid/item4.txt
# Processed: ../data/guideline_data/Advanced Mid/0.txt
# Created: ../data/guideline_data/Advanced Mid/item5.txt
# Created: ../data/guideline_data/Advanced Mid/item6.txt
# Created: ../data/guideline_data/Advanced Mid/item7.txt
# Created: ../data/guideline_data/Advanced Mid/item8.txt
# Created: ../data/guideline_data/Advanced Mid/item9.txt
# Processed: ../data/guideline_data/Advanced Mid/1.txt
# Created: ../data/guideline_data/Advanced Mid/item95.txt
# Created: ../data/guideline_data/Advanced Mid/item96.txt
# Created: ../data/guideline_data/Advanced Mid/item97.txt
# Created: ../data/guideline_data/Advanced Mid/item98.txt
# Created: ../data/guideline_data/Advanced Mid/item99.txt
# Processed: ../data/guideline_data/Advanced Mid/19.txt
# Created: ../data/guideline_data/Advanced Mid/item90.txt
# Created: ../data/guideline_data/Advanced Mid/item91.txt
# Created: ../data/guideline_data/Advanced Mid/item92.txt
# Created: ../data/guideline_data/Advanced Mid/item93.txt
# Created: ../data/guideline_data/Advanced Mid/item94.txt
# Processed: ../data/guideline_data/Advanced Mid/18.txt
# Created: ../data/guideline_data/Novice Mid/item75.txt
# ...
# Created: ../data/guideline_data/Advanced Low/item24.txt
# Processed: ../data/guideline_data/Advanced Low/4.txt
# Created: ../data/guideline_data/Advanced Low/item30.txt
# Created: ../data/guideline_data/Advanced Low/item31.txt
# Created: ../data/guideline_data/Advanced Low/item32.txt
# Created: ../data/guideline_data/Advanced Low/item33.txt
# Created: ../data/guideline_data/Advanced Low/item34.txt
# Processed: ../data/guideline_data/Advanced Low/6.txt
# Created: ../data/guideline_data/Advanced Low/item35.txt
# Created: ../data/guideline_data/Advanced Low/item36.txt
# Created: ../data/guideline_data/Advanced Low/item37.txt
# Created: ../data/guideline_data/Advanced Low/item38.txt
# Created: ../data/guideline_data/Advanced Low/item39.txt
# Processed: ../data/guideline_data/Advanced Low/7.txt
# Created: ../data/guideline_data/Advanced Low/item15.txt
# Created: ../data/guideline_data/Advanced Low/item16.txt
# Created: ../data/guideline_data/Advanced Low/item17.txt
# Created: ../data/guideline_data/Advanced Low/item18.txt
# Created: ../data/guideline_data/Advanced Low/item19.txt
# Processed: ../data/guideline_data/Advanced Low/3.txt
# Created: ../data/guideline_data/Advanced Low/item10.txt
# Created: ../data/guideline_data/Advanced Low/item11.txt
# Created: ../data/guideline_data/Advanced Low/item12.txt
# Created: ../data/guideline_data/Advanced Low/item13.txt
# Created: ../data/guideline_data/Advanced Low/item14.txt
# Processed: ../data/guideline_data/Advanced Low/2.txt
# Created: ../data/guideline_data/Advanced Low/item0.txt
# Created: ../data/guideline_data/Advanced Low/item1.txt
# Created: ../data/guideline_data/Advanced Low/item2.txt
# Created: ../data/guideline_data/Advanced Low/item3.txt
# Created: ../data/guideline_data/Advanced Low/item4.txt
# Processed: ../data/guideline_data/Advanced Low/0.txt
# Created: ../data/guideline_data/Advanced Low/item5.txt
# Created: ../data/guideline_data/Advanced Low/item6.txt
# Created: ../data/guideline_data/Advanced Low/item7.txt
# Created: ../data/guideline_data/Advanced Low/item8.txt
# Created: ../data/guideline_data/Advanced Low/item9.txt
# Processed: ../data/guideline_data/Advanced Low/1.txt
# Created: ../data/guideline_data/Advanced Low/item95.txt
# Created: ../data/guideline_data/Advanced Low/item96.txt
# Created: ../data/guideline_data/Advanced Low/item97.txt
# Created: ../data/guideline_data/Advanced Low/item98.txt
# Created: ../data/guideline_data/Advanced Low/item99.txt
# Processed: ../data/guideline_data/Advanced Low/19.txt
# Created: ../data/guideline_data/Advanced Low/item90.txt
# Created: ../data/guideline_data/Advanced Low/item91.txt
# Created: ../data/guideline_data/Advanced Low/item92.txt
# Created: ../data/guideline_data/Advanced Low/item93.txt
# Created: ../data/guideline_data/Advanced Low/item94.txt
# Processed: ../data/guideline_data/Advanced Low/18.txt
# Created: ../data/guideline_data/Novice Low/item75.txt
# Created: ../data/guideline_data/Novice Low/item76.txt
# Created: ../data/guideline_data/Novice Low/item77.txt
# Created: ../data/guideline_data/Novice Low/item78.txt
# Created: ../data/guideline_data/Novice Low/item79.txt
# Processed: ../data/guideline_data/Novice Low/15.txt
# Created: ../data/guideline_data/Novice Low/item70.txt
# Created: ../data/guideline_data/Novice Low/item71.txt
# Created: ../data/guideline_data/Novice Low/item72.txt
# Created: ../data/guideline_data/Novice Low/item73.txt
# Created: ../data/guideline_data/Novice Low/item74.txt
# Processed: ../data/guideline_data/Novice Low/14.txt
# Created: ../data/guideline_data/Novice Low/item80.txt
# Created: ../data/guideline_data/Novice Low/item81.txt
# Created: ../data/guideline_data/Novice Low/item82.txt
# Created: ../data/guideline_data/Novice Low/item83.txt
# Created: ../data/guideline_data/Novice Low/item84.txt
# Processed: ../data/guideline_data/Novice Low/16.txt
# Created: ../data/guideline_data/Novice Low/item85.txt
# Created: ../data/guideline_data/Novice Low/item86.txt
# Created: ../data/guideline_data/Novice Low/item87.txt
# Created: ../data/guideline_data/Novice Low/item88.txt
# Created: ../data/guideline_data/Novice Low/item89.txt
# Processed: ../data/guideline_data/Novice Low/17.txt
# Created: ../data/guideline_data/Novice Low/item65.txt
# Created: ../data/guideline_data/Novice Low/item66.txt
# Created: ../data/guideline_data/Novice Low/item67.txt
# Created: ../data/guideline_data/Novice Low/item68.txt
# Created: ../data/guideline_data/Novice Low/item69.txt
# Processed: ../data/guideline_data/Novice Low/13.txt
# Created: ../data/guideline_data/Novice Low/item60.txt
# Created: ../data/guideline_data/Novice Low/item61.txt
# Created: ../data/guideline_data/Novice Low/item62.txt
# Created: ../data/guideline_data/Novice Low/item63.txt
# Created: ../data/guideline_data/Novice Low/item64.txt
# Processed: ../data/guideline_data/Novice Low/12.txt
# Created: ../data/guideline_data/Novice Low/item50.txt
# Created: ../data/guideline_data/Novice Low/item51.txt
# Created: ../data/guideline_data/Novice Low/item52.txt
# Created: ../data/guideline_data/Novice Low/item53.txt
# Created: ../data/guideline_data/Novice Low/item54.txt
# Processed: ../data/guideline_data/Novice Low/10.txt
# Created: ../data/guideline_data/Novice Low/item55.txt
# Created: ../data/guideline_data/Novice Low/item56.txt
# Created: ../data/guideline_data/Novice Low/item57.txt
# Created: ../data/guideline_data/Novice Low/item58.txt
# Created: ../data/guideline_data/Novice Low/item59.txt
# Processed: ../data/guideline_data/Novice Low/11.txt
# Created: ../data/guideline_data/Novice Low/item45.txt
# Created: ../data/guideline_data/Novice Low/item46.txt
# Created: ../data/guideline_data/Novice Low/item47.txt
# Created: ../data/guideline_data/Novice Low/item48.txt
# Created: ../data/guideline_data/Novice Low/item49.txt
# Processed: ../data/guideline_data/Novice Low/9.txt
# Created: ../data/guideline_data/Novice Low/item40.txt
# Created: ../data/guideline_data/Novice Low/item41.txt
# Created: ../data/guideline_data/Novice Low/item42.txt
# Created: ../data/guideline_data/Novice Low/item43.txt
# Created: ../data/guideline_data/Novice Low/item44.txt
# Processed: ../data/guideline_data/Novice Low/8.txt
# Created: ../data/guideline_data/Novice Low/item25.txt
# Created: ../data/guideline_data/Novice Low/item26.txt
# Created: ../data/guideline_data/Novice Low/item27.txt
# Created: ../data/guideline_data/Novice Low/item28.txt
# Created: ../data/guideline_data/Novice Low/item29.txt
# Processed: ../data/guideline_data/Novice Low/5.txt
# Created: ../data/guideline_data/Novice Low/item20.txt
# Created: ../data/guideline_data/Novice Low/item21.txt
# Created: ../data/guideline_data/Novice Low/item22.txt
# Created: ../data/guideline_data/Novice Low/item23.txt
# Created: ../data/guideline_data/Novice Low/item24.txt
# Processed: ../data/guideline_data/Novice Low/4.txt
# Created: ../data/guideline_data/Novice Low/item30.txt
# Created: ../data/guideline_data/Novice Low/item31.txt
# Created: ../data/guideline_data/Novice Low/item32.txt
# Created: ../data/guideline_data/Novice Low/item33.txt
# Created: ../data/guideline_data/Novice Low/item34.txt
# Processed: ../data/guideline_data/Novice Low/6.txt
# Created: ../data/guideline_data/Novice Low/item35.txt
# Created: ../data/guideline_data/Novice Low/item36.txt
# Created: ../data/guideline_data/Novice Low/item37.txt
# Created: ../data/guideline_data/Novice Low/item38.txt
# Created: ../data/guideline_data/Novice Low/item39.txt
# Processed: ../data/guideline_data/Novice Low/7.txt
# Created: ../data/guideline_data/Novice Low/item15.txt
# Created: ../data/guideline_data/Novice Low/item16.txt
# Created: ../data/guideline_data/Novice Low/item17.txt
# Created: ../data/guideline_data/Novice Low/item18.txt
# Created: ../data/guideline_data/Novice Low/item19.txt
# Processed: ../data/guideline_data/Novice Low/3.txt
# Created: ../data/guideline_data/Novice Low/item10.txt
# Created: ../data/guideline_data/Novice Low/item11.txt
# Created: ../data/guideline_data/Novice Low/item12.txt
# Created: ../data/guideline_data/Novice Low/item13.txt
# Created: ../data/guideline_data/Novice Low/item14.txt
# Processed: ../data/guideline_data/Novice Low/2.txt
# Created: ../data/guideline_data/Novice Low/item0.txt
# Created: ../data/guideline_data/Novice Low/item1.txt
# Created: ../data/guideline_data/Novice Low/item2.txt
# Created: ../data/guideline_data/Novice Low/item3.txt
# Created: ../data/guideline_data/Novice Low/item4.txt
# Processed: ../data/guideline_data/Novice Low/0.txt
# Created: ../data/guideline_data/Novice Low/item5.txt
# Created: ../data/guideline_data/Novice Low/item6.txt
# Created: ../data/guideline_data/Novice Low/item7.txt
# Created: ../data/guideline_data/Novice Low/item8.txt
# Created: ../data/guideline_data/Novice Low/item9.txt
# Processed: ../data/guideline_data/Novice Low/1.txt
# Created: ../data/guideline_data/Novice Low/item95.txt
# Created: ../data/guideline_data/Novice Low/item96.txt
# Created: ../data/guideline_data/Novice Low/item97.txt
# Created: ../data/guideline_data/Novice Low/item98.txt
# Created: ../data/guideline_data/Novice Low/item99.txt
# Processed: ../data/guideline_data/Novice Low/19.txt
# Created: ../data/guideline_data/Novice Low/item90.txt
# Created: ../data/guideline_data/Novice Low/item91.txt
# Created: ../data/guideline_data/Novice Low/item92.txt
# Created: ../data/guideline_data/Novice Low/item93.txt
# Created: ../data/guideline_data/Novice Low/item94.txt
# Processed: ../data/guideline_data/Novice Low/18.txt
# Created: ../data/guideline_data/Distinguished/item75.txt
# Created: ../data/guideline_data/Distinguished/item76.txt
# Created: ../data/guideline_data/Distinguished/item77.txt
# Created: ../data/guideline_data/Distinguished/item78.txt
# Created: ../data/guideline_data/Distinguished/item79.txt
# Processed: ../data/guideline_data/Distinguished/15.txt
# Created: ../data/guideline_data/Distinguished/item70.txt
# Created: ../data/guideline_data/Distinguished/item71.txt
# Created: ../data/guideline_data/Distinguished/item72.txt
# Created: ../data/guideline_data/Distinguished/item73.txt
# Created: ../data/guideline_data/Distinguished/item74.txt
# Processed: ../data/guideline_data/Distinguished/14.txt
# Created: ../data/guideline_data/Distinguished/item80.txt
# Created: ../data/guideline_data/Distinguished/item81.txt
# Created: ../data/guideline_data/Distinguished/item82.txt
# Created: ../data/guideline_data/Distinguished/item83.txt
# Created: ../data/guideline_data/Distinguished/item84.txt
# Processed: ../data/guideline_data/Distinguished/16.txt
# Created: ../data/guideline_data/Distinguished/item85.txt
# Created: ../data/guideline_data/Distinguished/item86.txt
# Created: ../data/guideline_data/Distinguished/item87.txt
# Created: ../data/guideline_data/Distinguished/item88.txt
# Created: ../data/guideline_data/Distinguished/item89.txt
# Processed: ../data/guideline_data/Distinguished/17.txt
# Created: ../data/guideline_data/Distinguished/item65.txt
# Created: ../data/guideline_data/Distinguished/item66.txt
# Created: ../data/guideline_data/Distinguished/item67.txt
# Created: ../data/guideline_data/Distinguished/item68.txt
# Created: ../data/guideline_data/Distinguished/item69.txt
# Processed: ../data/guideline_data/Distinguished/13.txt
# Created: ../data/guideline_data/Distinguished/item60.txt
# Created: ../data/guideline_data/Distinguished/item61.txt
# Created: ../data/guideline_data/Distinguished/item62.txt
# Created: ../data/guideline_data/Distinguished/item63.txt
# Created: ../data/guideline_data/Distinguished/item64.txt
# Processed: ../data/guideline_data/Distinguished/12.txt
# Created: ../data/guideline_data/Distinguished/item50.txt
# Created: ../data/guideline_data/Distinguished/item51.txt
# Created: ../data/guideline_data/Distinguished/item52.txt
# Created: ../data/guideline_data/Distinguished/item53.txt
# Created: ../data/guideline_data/Distinguished/item54.txt
# Processed: ../data/guideline_data/Distinguished/10.txt
# Created: ../data/guideline_data/Distinguished/item55.txt
# Created: ../data/guideline_data/Distinguished/item56.txt
# Created: ../data/guideline_data/Distinguished/item57.txt
# Created: ../data/guideline_data/Distinguished/item58.txt
# Created: ../data/guideline_data/Distinguished/item59.txt
# Processed: ../data/guideline_data/Distinguished/11.txt
# Created: ../data/guideline_data/Distinguished/item45.txt
# Created: ../data/guideline_data/Distinguished/item46.txt
# Created: ../data/guideline_data/Distinguished/item47.txt
# Created: ../data/guideline_data/Distinguished/item48.txt
# Created: ../data/guideline_data/Distinguished/item49.txt
# Processed: ../data/guideline_data/Distinguished/9.txt
# Created: ../data/guideline_data/Distinguished/item40.txt
# Created: ../data/guideline_data/Distinguished/item41.txt
# Created: ../data/guideline_data/Distinguished/item42.txt
# Created: ../data/guideline_data/Distinguished/item43.txt
# Created: ../data/guideline_data/Distinguished/item44.txt
# Processed: ../data/guideline_data/Distinguished/8.txt
# Created: ../data/guideline_data/Distinguished/item25.txt
# Created: ../data/guideline_data/Distinguished/item26.txt
# Created: ../data/guideline_data/Distinguished/item27.txt
# Created: ../data/guideline_data/Distinguished/item28.txt
# Created: ../data/guideline_data/Distinguished/item29.txt
# Processed: ../data/guideline_data/Distinguished/5.txt
# Created: ../data/guideline_data/Distinguished/item20.txt
# Created: ../data/guideline_data/Distinguished/item21.txt
# Created: ../data/guideline_data/Distinguished/item22.txt
# Created: ../data/guideline_data/Distinguished/item23.txt
# Created: ../data/guideline_data/Distinguished/item24.txt
# Processed: ../data/guideline_data/Distinguished/4.txt
# Created: ../data/guideline_data/Distinguished/item30.txt
# Created: ../data/guideline_data/Distinguished/item31.txt
# Created: ../data/guideline_data/Distinguished/item32.txt
# Created: ../data/guideline_data/Distinguished/item33.txt
# Created: ../data/guideline_data/Distinguished/item34.txt
# Processed: ../data/guideline_data/Distinguished/6.txt
# Created: ../data/guideline_data/Distinguished/item35.txt
# Created: ../data/guideline_data/Distinguished/item36.txt
# Created: ../data/guideline_data/Distinguished/item37.txt
# Created: ../data/guideline_data/Distinguished/item38.txt
# Created: ../data/guideline_data/Distinguished/item39.txt
# Processed: ../data/guideline_data/Distinguished/7.txt
# Created: ../data/guideline_data/Distinguished/item15.txt
# Created: ../data/guideline_data/Distinguished/item16.txt
# Created: ../data/guideline_data/Distinguished/item17.txt
# Created: ../data/guideline_data/Distinguished/item18.txt
# Created: ../data/guideline_data/Distinguished/item19.txt
# Processed: ../data/guideline_data/Distinguished/3.txt
# Created: ../data/guideline_data/Distinguished/item10.txt
# Created: ../data/guideline_data/Distinguished/item11.txt
# Created: ../data/guideline_data/Distinguished/item12.txt
# Created: ../data/guideline_data/Distinguished/item13.txt
# Created: ../data/guideline_data/Distinguished/item14.txt
# Processed: ../data/guideline_data/Distinguished/2.txt
# Created: ../data/guideline_data/Distinguished/item0.txt
# Created: ../data/guideline_data/Distinguished/item1.txt
# Created: ../data/guideline_data/Distinguished/item2.txt
# Created: ../data/guideline_data/Distinguished/item3.txt
# Created: ../data/guideline_data/Distinguished/item4.txt
# Processed: ../data/guideline_data/Distinguished/0.txt
# Created: ../data/guideline_data/Distinguished/item5.txt
# Created: ../data/guideline_data/Distinguished/item6.txt
# Created: ../data/guideline_data/Distinguished/item7.txt
# Created: ../data/guideline_data/Distinguished/item8.txt
# Created: ../data/guideline_data/Distinguished/item9.txt
# Processed: ../data/guideline_data/Distinguished/1.txt
# Created: ../data/guideline_data/Distinguished/item95.txt
# Created: ../data/guideline_data/Distinguished/item96.txt
# Created: ../data/guideline_data/Distinguished/item97.txt
# Created: ../data/guideline_data/Distinguished/item98.txt
# Created: ../data/guideline_data/Distinguished/item99.txt
# Processed: ../data/guideline_data/Distinguished/19.txt
# Created: ../data/guideline_data/Distinguished/item90.txt
# Created: ../data/guideline_data/Distinguished/item91.txt
# Created: ../data/guideline_data/Distinguished/item92.txt
# Created: ../data/guideline_data/Distinguished/item93.txt
# Created: ../data/guideline_data/Distinguished/item94.txt
# Processed: ../data/guideline_data/Distinguished/18.txt
